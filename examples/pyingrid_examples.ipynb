# %% [markdown]
# # PyIngrid Examples
# * Wenchang Yang (yang.wenchang@uci.edu)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-notebook')

# %%
Ingrid('ersst4').do('[T]average').to_xarray().geo.plot(fill_continents=True, 
                                                       cmap='viridis', plot_type='contourf+', levels=range(-5,30,2),
                                                      long_name='ERSST4', units='$^0$C')
# Out:
# /home/wenchay/miniconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3630: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/wenchay/miniconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3699: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/wenchay/miniconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3527: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/wenchay/miniconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3594: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
cd ~/mydata
# Out:
# /home/wenchay/mydata

# %%
ls
# Out:
# __backup_scripts_in_mydata.sh  era20c/  mjo/    simu/    trmm/
# __backup_to_surtsey.py         erai/    noaa/   sst/     weather_regimes_erai/
# byproj/                        gpcp/    nsidc/  __test/  weather_regimes_ncep/
# cesmLE/                        itcz/    olr/    topo.nc

# %%
Ingrid('topo.nc')
# Out:
# <class 'pyingrid.ingrid.Ingrid'>
# topo.nc

# %%
da = Ingrid('topo.nc').to_xarray()

# %%
da
# Out:
# <xarray.DataArray 'topo' (lat: 360, lon: 720)>
# [259200 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 -177.8 -177.2 -176.8 ...
#   * lat      (lat) float64 -89.75 -89.25 -88.75 -88.25 -87.75 -87.25 -86.75 ...
# Attributes:
#     units: m

# %%
da.geo.plot(coastlines_color='none',
           units='m')
plt.title('World\' Topography')
# Out:
# plot_type **** pcolormesh **** is used.
# /home/wenchay/miniconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3435: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/wenchay/miniconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3444: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
da.geo.plot(coastlines_color='none', units='m', proj='ortho', lon_0=90, lat_0=30)
plt.title('World\'s Topography')
# Out:
# plot_type **** pcolor **** is used.
# /home/wenchay/miniconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3360: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/wenchay/miniconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3399: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
